# %%
dbutils.widgets.text("catalog_name", "23283_dev")

# %%
# %sql
OPTIMIZE `23283_dev`.gold_23283.fact_sales
ZORDER BY (customer_id, product_id);

# %%
# %sql
SELECT * FROM `23283_dev`.gold_23283.fact_sales VERSION AS OF 1;

# %%
# %sql
VACUUM `23283_dev`.gold_23283.fact_sales RETAIN 168 HOURS;
