# %%
# %sql
--Creating Dev Catalog
CREATE CATALOG IF NOT EXISTS 23283_dev; 
--Creating Uat Catalog
CREATE CATALOG IF NOT EXISTS 23283_uat;
--Creating Prod Catalog
CREATE CATALOG IF NOT EXISTS 23283_prod; 

USE CATALOG 23283_dev;

--Creating bronze Schema
CREATE SCHEMA IF NOT EXISTS bronze_23283;
--Creating silver Schema
CREATE SCHEMA IF NOT EXISTS silver_23283;
--Creating gold Schema
CREATE SCHEMA IF NOT EXISTS gold_23283;
-- creating metadata schema
CREATE SCHEMA IF NOT EXISTS metadata_23283;

# %%
# %sql
USE CATALOG 23283_uat;

--Creating bronze Schema
CREATE SCHEMA IF NOT EXISTS bronze_23283;
--Creating silver Schema
CREATE SCHEMA IF NOT EXISTS silver_23283;
--Creating gold Schema
CREATE SCHEMA IF NOT EXISTS gold_23283;
-- creating metadata schema
CREATE SCHEMA IF NOT EXISTS metadata_23283;

# %%
# %sql
USE CATALOG 23283_prod;

--Creating bronze Schema
CREATE SCHEMA IF NOT EXISTS bronze_23283;
--Creating silver Schema
CREATE SCHEMA IF NOT EXISTS silver_23283;
--Creating gold Schema
CREATE SCHEMA IF NOT EXISTS gold_23283;
-- creating metadata schema
CREATE SCHEMA IF NOT EXISTS metadata_23283;
