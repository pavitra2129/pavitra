# %% [markdown]
# ### Step 1: Reading or extracting

# %%
from pyspark.sql.functions import *

# %%
df=spark.read.csv("/Volumes/acc_dev/naval/raw/financial_dataset.csv",header=True,inferSchema=True)

# %% [markdown]
# ### Step 2: Transformation

# %%
df.display()

# %% [markdown]
# - Lazy evaluation
#
# Transformation
# - read
# - select(df["colunn1"],df.column1--useful while joining two columns from 2 tables with same column name )
# - select (col(column1))
# - filter
# - sort
# - withColumnRenamed
# - withColumn
# - groupby
#
# Actions
# - show
# - display
# - write
#
# Functions
# - col
# - current_date
# - lit
# - concat

# %%
df.select("CustomerID","TransactionID")

# %%
df1=df.filter("CustomerID='CUST0007")

# %%
df.filter("CustomerID='CUST0007'").explain(True)

# %%
df.filter("CustomerID='CUST0007'").display()

# %%
df.select("CustomerID","TransactionID").display()

# %%
df.select("AccountType")

# %%
df.select("CustomerID".alias("cust_id"))

# %%
df.select(col("CustomerID").alias("cust_id"))

# %%
df.select("CustomerID",col("TransactionID"),df.AccountType,df["AmountUSD"]).display()

# %%
df.select(col("CustomerID").alias("cust_id"))

# %%
df.withColumnRenamed("CustomerID","cust_id").withColumnRenamed("TransactionID","transaction_id").display()

# %%
df1=df.withColumnsRenamed({"CustomerID":"cust_id","TransactionID":"transaction_id"})

# %%
df.withColumn("Branch",upper("Branch")).display()

# %%
df.withColumn("ingestion_date",current_timestamp()).display()
