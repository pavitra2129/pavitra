# %% [markdown]
# Spark:
# Parallel processing
#
# - RDD
# - Data Frame
# - DS
#
# After 3.5 version all are Dataframes

# %% [markdown]
# ### DataFrame

# %%
data=([(1,'abc'),(2,'b'),(3,'c')])
schema=['id','name']
df=spark.createDataFrame(data,schema)

# %%
# show command will work in any platform
# display is only work in databricks
df.show()

# %%
df.display()

# %% [markdown]
# ### Difference between pandas and pyspark Dataframe
# - pandas will use single compute- no parallelism
# - in pyspark we can achieve parallelism

# %%
from datetime import datetime, date
import pandas as pd
from pyspark.sql import Row

df = spark.createDataFrame([
    Row(a=1, b=2., c='string1', d=date(2000, 1, 1), e=datetime(2000, 1, 1, 12, 0)),
    Row(a=2, b=3., c='string2', d=date(2000, 2, 1), e=datetime(2000, 1, 2, 12, 0)),
    Row(a=4, b=5., c='string3', d=date(2000, 3, 1), e=datetime(2000, 1, 3, 12, 0))
])
df

# %%
df.show()

# %%
df = spark.createDataFrame([
    (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
    (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
    (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
], schema='a long, b double, c string, d date, e timestamp')
df

# %%
df.show()

# %% [markdown]
# ### Reader API

# %%
#df_sales=spark.read.csv("/Volumes/acc_dev/pavitra/raw/csv/sales.csv")
df_sales=spark.read.csv("/Volumes/acc_dev/pavitra/raw/csv/sales.csv",header=True,inferSchema=True)

# %%
df.show()

# %% [markdown]
# ### Writer API

# %%
# %sql
drop table if exists acc_dev.pavitra.sales_py

# %%
df_sales.write.saveAsTable("acc_dev.pavitra.sales_py")

# %%
df_sales=spark.read.csv("Volumes/acc_dev/pavitra/raw/sales.csv",header=True,inferSchema=True)
df_sales.write.mode("overwrite").saveAsTable("acc_dev.pavitra.sales_py")

# %%
(spark
 .read
 .csv("/Volumes/acc_dev/pavitra/raw/csv/sales.csv",header=True,inferSchema=True)
 .write
 .mode("overwrite")
 .saveAsTable("acc_dev.pavitra.sales_py"))

# %%
# %sql
select * from acc_dev.pavitra.sales_py

# %%
df_sales.display()

# %%
df_house=spark.read.parquet("/Volumes/acc_dev/naval/raw/house-price.parquet")

# %%
df_house.write.mode("append").saveAsTable("acc_dev.pavitra.house_py")

# %%
# %sql
select * from acc_dev.pavitra.house_py

# %% [markdown]
# reading and writing json file

# %%
df_json=spark.read.json("/Volumes/acc_dev/naval/raw/retail_orders.json")
