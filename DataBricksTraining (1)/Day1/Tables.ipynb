# %% [markdown]
# ### Ways to create a table
# -  pyspark dataframe
# -  CTAS
# -  UI

# %%
# %sql
select
  sum(case when order_id is null then 1 else 0 end) as order_id_nulls,
  sum(case when customer_id is null then 1 else 0 end) as customer_id_nulls,
  sum(case when transaction_id is null then 1 else 0 end) as transaction_id_nulls,
  sum(case when product_id is null then 1 else 0 end) as product_id_nulls,
  sum(case when quantity is null then 1 else 0 end) as quantity_nulls,
  sum(case when discount_amount is null then 1 else 0 end) as discount_amount_nulls,
  sum(case when total_amount is null then 1 else 0 end) as total_amount_nulls,
  sum(case when order_date is null then 1 else 0 end) as order_date_nulls
from acc_dev.pavitra.sales;

# %%
# %sql
Drop table if exists acc_dev.pavitra.house_price;
