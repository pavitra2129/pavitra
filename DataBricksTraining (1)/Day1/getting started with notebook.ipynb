# %% [markdown]
# ### DataBricks Notebooks

# %%
print("hello")

# %%
# %sql
select "Run SQL"

# %% [markdown]
# ### Data Objects
#
# - Catalog
# - schema
# - tables, views, volumes, functions

# %% [markdown]
# ![](/Volumes/acc_dev/naval/raw/object-model.png)

# %% [markdown]
# **create schema**

# %%
# %sql
use catalog acc_dev;
create schema if not exists pavitra;

# %% [markdown]
# **OR**

# %%
# %sql
create schema if not exists acc_dev.pavitra;

# %% [markdown]
#  **Create Table**

# %%
# %sql
create table acc_dev.pavitra.demo(id int primary key)
