# %%
# %sql
use catalog acc_dev;
use schema pavitra;

# %%
# %sql
create table if not exists emp(id int, name string, city string)

# %%
# %sql
insert into emp values (1,'Naval','Solapur')

# %%
# %sql
select * from emp

# %%
# %sql desc extended emp

# %%
# %sql
desc history emp

# %%
# %sql
desc detail emp

# %%
# %sql
delete from acc_dev.pavitra.emp where id=1

# %% [markdown]
# ### Time travel

# %%
# %sql
select * from acc_dev.pavitra.emp version as of 2

# %%
# %sql
insert into acc_dev.pavitra.emp (id, name, city) values (1, "pavi", "hyd")

# %%
# %sql
create table empv3 as
select * from acc_dev.pavitra.emp version as of 3

# %%
# %sql
insert into acc_dev.naval.emp values (23283,'Pavitra','Hyderabad')

# %%
# %sql
select * from acc_dev.naval.emp timestamp as of '2025-11-05T05:09:38.000+00:00'

# %%
# %sql
delete from acc_dev.pavitra.emp

# %%
# %sql
select * from emp

# %% [markdown]
# ### Restore

# %%
# %sql
restore table emp to version as of 3

# %%
# %sql
select * from emp
