# %%
data=([(1,'Virat'),(2,'Rohit')])
schema="id int, name string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("overwrite").saveAsTable("acc_dev.pavitra.cricket")

# %%
# %sql
select * from acc_dev.pavitra.cricket

# %%
data=([(3,'Sachin'),(4,'Dhoni')])
schema="id int, name string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("append").saveAsTable("acc_dev.pavitra.cricket")

# %%
# %sql
select * from acc_dev.pavitra.cricket

# %%
data=([(5,'sky','All Rounder'),(6,'Shubnam','Batsman')])
schema="id int, name string, role string"

df=spark.createDataFrame(data,schema)
display(df)

# %% [markdown]
# ### mergeSchema

# %%
df.write.mode("append").option("mergeSchema", "true").saveAsTable("acc_dev.pavitra.cricket")

# %%
df=spark.table("acc_dev.pavitra.cricket")

# %%
# %sql
select * from acc_dev.pavitra.cricket

# %% [markdown]
# ### Ho wto create iceberg table

# %%
df.write.format("iceberg").saveAsTable("acc_dev.pavitra.iceberg")
