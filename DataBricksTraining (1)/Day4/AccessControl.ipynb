# %%
grant privilege on object object_name to principal_name;

# %%
revoke privilege on object object_name from name;

# %%
show grants on catalog acc_dev

# %%
revoke use catalog on catalog acc_dev from `account users`

# %%
# %sql
grant use catalog on catalog acc_dev to `account users`

# %%
# %sql
grant use schema on schema acc_dev.pavitra_bronze to `chilumularishi@gmail.com`;
grant create table on schema acc_dev.pavitra_bronze to `chilumularishi@gmail.com`;
--grant
